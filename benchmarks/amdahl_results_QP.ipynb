# %%
using DataFrames
using SolverBenchmark
using SolverTools
using JLD2

# %%
res_path = "C:\\Users\\Geoffroy Leconte\\Documents\\cours\\TFE\\code\\StageOptim\\amdahl_benchmarks\\results"
# gurobi_path = "C:\\Users\\Geoffroy Leconte\\Documents\\cours\\TFE\\code\\results\\gurobi"
# cplex_path = "C:\\Users\\Geoffroy Leconte\\Documents\\cours\\TFE\\code\\results\\cplex"

# %%
# ρ_min, δ_min = 1e-5*T(sqrt(eps())), 1e0*T(sqrt(eps()))
# file_test = jldopen(string(res_path, "\\mehrotra_qp_test.jld2"), "r") 
# mehrotra_test = file_test["stats"];
# close(file_test)
# file_test2 = jldopen(string(res_path, "\\mehrotra_qp_test2.jld2"), "r") 
# mehrotra_test2 = file_test2["stats"];
# close(file_test2)

#gurobi
fgur1 = jldopen(string(res_path, "\\gurobi_scaling_qp.jld2"), "r") 
gurobi1 = fgur1["stats"];
close(fgur1)
fgur2 = jldopen(string(res_path, "\\gurobi_scaling_qp2.jld2"), "r") 
gurobi2 = fgur2["stats"];
close(fgur2)
fgur3 = jldopen(string(res_path, "\\gurobi_scaling_qp3.jld2"), "r")  # no display
gurobi3 = fgur3["stats"];
close(fgur3)
fgur4 = jldopen(string(res_path, "\\gurobi_scaling_qp4.jld2"), "r")  # maj + single thread
gurobi4 = fgur4["stats"];
close(fgur4)

#cplex
fcplex1 = jldopen(string(res_path, "\\cplex_scaling_qp1.jld2"), "r") 
cplex1 = fcplex1["stats"];
close(fcplex1)
fcplex2 = jldopen(string(res_path, "\\cplex_scaling_qp2.jld2"), "r") # maj cplex.jl, multiple threads 
cplex2 = fcplex2["stats"];
close(fcplex2)
fcplex3 = jldopen(string(res_path, "\\cplex_scaling_qp3.jld2"), "r") # maj cplex.jl, single thread
cplex3 = fcplex3["stats"];
close(fcplex3)

# xpress1
fxpress1 = jldopen(string(res_path, "\\xpress_scaling_qp1.jld2"), "r") 
xpress1 = fxpress1["stats"];
close(fxpress1)
fxpress2 = jldopen(string(res_path, "\\xpress_scaling_qp2.jld2"), "r")  #tol pdd 1e-8, feas 1e-6
xpress2 = fxpress2["stats"];
close(fxpress2)

# # same with init diag 1e-2
# file1 = jldopen(string(res_path, "\\mehrotra_qp1.jld2"), "r") 
# mehrotra1 = file1["stats"];
# close(file1)
# # same with init diag 1e-1, ρ0=1e5*sqrt(eps()), δ0=1e6*sqrt(eps)
# file2 = jldopen(string(res_path, "\\mehrotra_qp2.jld2"), "r") 
# mehrotra2 = file2["stats"];
# close(file2)
# # init diag 1e-0, ρ0=1e5*sqrt(eps()), δ0=1e8*sqrt(eps)
# file3 = jldopen(string(res_path, "\\mehrotra_qp3.jld2"), "r") 
# mehrotra3 = file3["stats"];
# close(file3)
# # init diag 1e-0/2, ρ0=1e5*sqrt(eps()), δ0=1e5*sqrt(eps)
# file4 = jldopen(string(res_path, "\\mehrotra_qp4.jld2"), "r") 
# mehrotra4 = file4["stats"];
# close(file4)
# # same 4 with ϵ_pdd=1e-6
# file4bis = jldopen(string(res_path, "\\mehrotra_qp4bis.jld2"), "r") 
# mehrotra4bis = file4bis["stats"];
# close(file4bis)
# # init diag 1e-0/2, ρ0=1e5*sqrt(eps()), δ0=1e5*sqrt(eps), s/x_m_lvar control
# file5 = jldopen(string(res_path, "\\mehrotra_qp5.jld2"), "r") 
# mehrotra5 = file5["stats"];
# close(file5)
# # init diag 1e-0/2, ρ0=1e5*sqrt(eps()), δ0=1e5*sqrt(eps), s/x_m_lvar control with ϵ_pdd=1e-6
# file5bis = jldopen(string(res_path, "\\mehrotra_qp5bis.jld2"), "r") 
# mehrotra5bis = file5bis["stats"];
# close(file5bis)
# # init diag 1e-0/2, ρ0=1e5*sqrt(eps()), δ0=1e5*sqrt(eps), diag_J control (-1 / min(δ,ρ) / 1e-1)
# file6 = jldopen(string(res_path, "\\mehrotra_qp6.jld2"), "r") 
# mehrotra6 = file6["stats"];
# close(file6)
# # init diag 1e-0/2, ρ0=1e5*sqrt(eps()), δ0=1e5*sqrt(eps),  diag_J control 1/min(ρ, δ)/1e-1 with ϵ_pdd=1e-6
# file6bis = jldopen(string(res_path, "\\mehrotra_qp6bis.jld2"), "r") 
# mehrotra6bis = file6bis["stats"];
# close(file6bis)
# # init diag 1e-0/2, ρ0=1e5*sqrt(eps()), δ0=1e5*sqrt(eps), diag_J control -1 / δ / 1e-8 
# file7 = jldopen(string(res_path, "\\mehrotra_qp7.jld2"), "r") 
# mehrotra7 = file7["stats"];
# close(file7)
# # init diag 1e-0/2, ρ0=1e5*sqrt(eps()), δ0=1e5*sqrt(eps), diag_J control -1 / δ / 1e-8 with ϵ_pdd=1e-6
# file7bis = jldopen(string(res_path, "\\mehrotra_qp7bis.jld2"), "r") 
# mehrotra7bis= file7bis["stats"];
# close(file7bis)
# # init diag 1e-0/2, ρ0=1e5*sqrt(eps()), δ0=1e5*sqrt(eps), diag_J control -1 / δ / 1e-6
# file8 = jldopen(string(res_path, "\\mehrotra_qp8.jld2"), "r") 
# mehrotra8 = file8["stats"];
# close(file8)
# file8bis = jldopen(string(res_path, "\\mehrotra_qp8bis.jld2"), "r") 
# mehrotra8bis = file8bis["stats"];
# close(file8bis)
# same with inf norm for rb and rc
# file9 = jldopen(string(res_path, "\\mehrotra_qp9.jld2"), "r") 
# mehrotra9 = file9["stats"];
# close(file9)
# # same with inf norm for rb and rc (rc and rb matching tulip)
# file9t = jldopen(string(res_path, "\\mehrotra_qp9t.jld2"), "r") 
# mehrotra9t = file9t["stats"];
# close(file9t)
# # same with inf norm for rb and rc with ϵ_pdd=1e-6
# file9bis = jldopen(string(res_path, "\\mehrotra_qp9bis.jld2"), "r") 
# mehrotra9bis = file9bis["stats"];
# close(file9bis)
# # same J_fact in init_pts
# file10 = jldopen(string(res_path, "\\mehrotra_qp10.jld2"), "r") 
# mehrotra10 = file10["stats"];
# close(file10)
# # same with d3.=1
# file11 = jldopen(string(res_path, "\\mehrotra_qp11.jld2"), "r") 
# mehrotra11 = file11["stats"];
# close(file11)
# # same 9 with rc, rb <= ϵ_rc,ϵ_rb
# file12 = jldopen(string(res_path, "\\mehrotra_qp12.jld2"), "r") 
# mehrotra12 = file12["stats"];
# close(file12)

# %%
 # ripqp mono
# file_rip_mono1 = jldopen(string(res_path, "\\ripqp_qp_mono1.jld2"), "r") 
# ripqp_mono1 = file_rip_mono1["stats"];
# close(file_rip_mono1)
# file_rip_mono2 = jldopen(string(res_path, "\\ripqp_qp_mono_2.jld2"), "r") # no SlackModel
# ripqp_mono2 = file_rip_mono2["stats"];
# close(file_rip_mono2)
# file_rip_mono3 = jldopen(string(res_path, "\\ripqp_qp_mono_3.jld2"), "r")  # iterative refinement classic mode
# ripqp_mono3 = file_rip_mono3["stats"];
# close(file_rip_mono3)
file_rip_mono4 = jldopen(string(res_path, "\\ripqp_qp_mono_4.jld2"), "r")  # default ldl
ripqp_mono4 = file_rip_mono4["stats"];
close(file_rip_mono4)
file_rip_mono5 = jldopen(string(res_path, "\\ripqp_qp_mono_5.jld2"), "r")  # new ldl
ripqp_mono5 = file_rip_mono5["stats"];
close(file_rip_mono5)
file_rip_mono6 = jldopen(string(res_path, "\\ripqp_qp_mono_6.jld2"), "r")  # reference
ripqp_mono6 = file_rip_mono6["stats"];
close(file_rip_mono6)

# multiple centrality corr
file_rip_mono_c0 = jldopen(string(res_path, "\\ripqp_qp_mono_c0.jld2"), "r")  # K=0
ripqp_mono_c0 = file_rip_mono_c0["stats"];
close(file_rip_mono_c0)
file_rip_mono_c1 = jldopen(string(res_path, "\\ripqp_qp_mono_c1.jld2"), "r")  # K = 2
ripqp_mono_c1 = file_rip_mono_c1["stats"];
close(file_rip_mono_c1)
file_rip_mono_c2 = jldopen(string(res_path, "\\ripqp_qp_mono_c2.jld2"), "r")  # K=-1, Es=16n
ripqp_mono_c2 = file_rip_mono_c2["stats"];
close(file_rip_mono_c2)
file_rip_mono_c3 = jldopen(string(res_path, "\\ripqp_qp_mono_c3.jld2"), "r")  # K=-1, Es=13n 
ripqp_mono_c3 = file_rip_mono_c3["stats"];
close(file_rip_mono_c3)
file_rip_mono_c4 = jldopen(string(res_path, "\\ripqp_qp_mono_c4.jld2"), "r")  #  K=-1, Es=12n
ripqp_mono_c4 = file_rip_mono_c4["stats"];
close(file_rip_mono_c4)
file_rip_mono_c5 = jldopen(string(res_path, "\\ripqp_qp_mono_c5.jld2"), "r")  #  K=-1, Es=14n
ripqp_mono_c5 = file_rip_mono_c5["stats"];
close(file_rip_mono_c5)

file_rip_mono_d2 = jldopen(string(res_path, "\\ripqp_qp_mono_d2.jld2"), "r")  #dynamic regul
ripqp_mono_d2 = file_rip_mono_d2["stats"];
close(file_rip_mono_d2)
file_rip_mono_d3 = jldopen(string(res_path, "\\ripqp_qp_mono_d3.jld2"), "r")  #dr δ=sqrt(eps)*10, init diag 1e-6/2
ripqp_mono_d3 = file_rip_mono_d3["stats"];
close(file_rip_mono_d3)
#dr  δ=sqrt(eps)*10, init diag 1e0/2  update structs
file_rip_mono_d4 = jldopen(string(res_path, "\\ripqp_qp_mono_d4.jld2"), "r")  
ripqp_mono_d4 = file_rip_mono_d4["stats"];
close(file_rip_mono_d4)
# δ = sqrt(eps()), init diag 1/2
file_rip_mono_d5 = jldopen(string(res_path, "\\ripqp_qp_mono_d5.jld2"), "r")  
ripqp_mono_d5 = file_rip_mono_d5["stats"];
close(file_rip_mono_d5)
# iterative refinement correc δ
file_rip_mono_d6 = jldopen(string(res_path, "\\ripqp_qp_mono_d6.jld2"), "r")  
ripqp_mono_d6 = file_rip_mono_d6["stats"];
close(file_rip_mono_d6)
# iterative refinement no correc δ
file_rip_mono_d7 = jldopen(string(res_path, "\\ripqp_qp_mono_d7.jld2"), "r")  
ripqp_mono_d7 = file_rip_mono_d7["stats"];
close(file_rip_mono_d7)
# iterative refinement (normalized rhs) no correc δ 
file_rip_mono_d8 = jldopen(string(res_path, "\\ripqp_qp_mono_d8.jld2"), "r")  
ripqp_mono_d8 = file_rip_mono_d8["stats"];
close(file_rip_mono_d8)
# ripqp v0.1 ρ=eps()^1/2 
file_rip_mono_d9 = jldopen(string(res_path, "\\ripqp_qp_mono_d9.jld2"), "r")  
ripqp_mono_d9 = file_rip_mono_d9["stats"];
close(file_rip_mono_d9)

# dynamic regul2 multi precision default params
file_rip_mp_d1 = jldopen(string(res_path, "\\ripqp_qp_mp_d1.jld2"), "r")  
ripqp_mp_d1 = file_rip_mp_d1["stats"];
close(file_rip_mp_d1)

# multi precision ITER X4
# starting diag -1e-4
file_mp1 = jldopen(string(res_path, "\\mehrotra_qp_mp1.jld2"), "r") 
mehrotra_mp1 = file_mp1["stats"];
close(file_mp1)
# starting diag -1e0
file_mp2 = jldopen(string(res_path, "\\mehrotra_qp_mp2.jld2"), "r") 
mehrotra_mp2 = file_mp2["stats"];
close(file_mp2)
 # starting diag -1e-4, ϵ_32=1e-2 (previously 1e-1)
file_mp3 = jldopen(string(res_path, "\\mehrotra_qp_mp3.jld2"), "r") 
mehrotra_mp3 = file_mp3["stats"];
close(file_mp3)
 # starting diag -1e0, ϵ_32=1e-2 (previously 1e-1)
file_mp4 = jldopen(string(res_path, "\\mehrotra_qp_mp4.jld2"), "r") 
mehrotra_mp4 = file_mp4["stats"];
close(file_mp4)
 # starting diag -1e-2, ϵ_32=1e-2
file_mp5 = jldopen(string(res_path, "\\mehrotra_qp_mp5.jld2"), "r") 
mehrotra_mp5 = file_mp5["stats"];
close(file_mp5)
 # starting diag -1e0, ϵ_32=1e-2, ϵ_32_pdd=1e-1   
file_mp6 = jldopen(string(res_path, "\\mehrotra_qp_mp6.jld2"), "r") 
mehrotra_mp6 = file_mp6["stats"];
close(file_mp6)
 # same mp5 with d3=1
file_mp7 = jldopen(string(res_path, "\\mehrotra_qp_mp7.jld2"), "r") 
mehrotra_mp7 = file_mp7["stats"];
close(file_mp7)

 # same mp5 with init ρ, δ = sqrt(eps())*1e8, sqrt(eps())*1e9
file_rip_mp1 = jldopen(string(res_path, "\\ripqp_qp_mp1.jld2"), "r") 
ripqp_mp1 = file_rip_mp1["stats"];
close(file_rip_mp1)
#same mp5, with max_iter32=30, , ϵ_rc32 = 1e-3, 1e-3,  ϵ_pdd32=1e-2
file_rip_mp2 = jldopen(string(res_path, "\\ripqp_qp_mp2.jld2"), "r") 
ripqp_mp2 = file_rip_mp2["stats"];
close(file_rip_mp2)
#same mp5, with max_iter32=30, , ϵ_rc32 = 1e-4, 1e-4, ϵ_pdd32=1e-3, maxiter32=30
file_rip_mp3 = jldopen(string(res_path, "\\ripqp_qp_mp3.jld2"), "r") 
ripqp_mp3 = file_rip_mp3["stats"];
close(file_rip_mp3)
#same ripqp_mp3 with LDLFact v 0.6
file_rip_mp4 = jldopen(string(res_path, "\\ripqp_qp_mp4.jld2"), "r") 
ripqp_mp4 = file_rip_mp4["stats"];
close(file_rip_mp4)
#same ripqp_mp4 with transition
file_rip_mp5 = jldopen(string(res_path, "\\ripqp_qp_mp5.jld2"), "r") 
ripqp_mp5 = file_rip_mp5["stats"];
close(file_rip_mp5)

# %%
## benchmarks G-2021-03
file_G1_mono = jldopen(string(res_path, "\\G-2021-03_qp_mono.jld2"), "r") 
ripqp_G1_mono = file_G1_mono["stats"];
close(file_G1_mono)
file_G1_mono_c = jldopen(string(res_path, "\\G-2021-03_qp_mono_c.jld2"), "r") # K=-1
ripqp_G1_mono_c = file_G1_mono_c["stats"];
close(file_G1_mono_c)
file_G1_mono_d = jldopen(string(res_path, "\\G-2021-03_qp_mono_d.jld2"), "r") # dynamic regul K=0
ripqp_G1_mono_d = file_G1_mono_d["stats"];
close(file_G1_mono_d)
file_G1_multi = jldopen(string(res_path, "\\G-2021-03_qp_multi.jld2"), "r") # multi mode, classic regul, K=0
ripqp_G1_multi = file_G1_multi["stats"];
close(file_G1_multi)
# file_G1_multi_d = jldopen(string(res_path, "\\G-2021-03_qp_multi_d.jld2"), "r") # multi mode, dynamic regul, K=0
# ripqp_G1_multi_d = file_G1_multi_d["stats"];
# close(file_G1_multi_d)

# %%
withenv("COLUMNS" => 120, "LINES" => 130) do
    display(ripqp_mono4)
end

# %%
stats = Dict(#:gurobi2=>gurobi2, 
#             :gurobi3=>gurobi3, 
#               :gurobi4=>gurobi4,
#             :cplex1=>cplex1,
#               :cplex2=>cplex2,
#               :cplex3=>cplex3,
#               :xpress1=>xpress1,
#               :xpress2=>xpress2,
#               :mehrotra11=>mehrotra11,
             # :mehrotra9=>mehrotra9,
              #:mehrotra9t=>mehrotra9t,
              #:mehrotra_mp1=>mehrotra_mp1
                # :mehrotra12=>mehrotra12,
#                 :ripqp_mono1=>ripqp_mono1,
#                 :ripqp_mono2=>ripqp_mono2,
#                 :ripqp_mono3=>ripqp_mono3,
                :ripqp_mono4=>ripqp_mono4,
                :ripqp_mono5=>ripqp_mono5,
                 :ripqp_mono6=>ripqp_mono6,
#         :ripqp_mono_d2=>ripqp_mono_d2,
#         :ripqp_mono_d3=>ripqp_mono_d3,
#         :ripqp_mono_d4=>ripqp_mono_d4,
#             :ripqp_mono_d5=>ripqp_mono_d5,
#         :ripqp_mono_d6=>ripqp_mono_d6,
#     :ripqp_mono_d7=>ripqp_mono_d7,
#     :ripqp_mono_d8=>ripqp_mono_d8,
#       :ripqp_mono_d9=>ripqp_mono_d9,
#       :ripqp_mono_c0=>ripqp_mono_c0,
#     :ripqp_mono_c1=>ripqp_mono_c1,
#     :ripqp_mono_c2=>ripqp_mono_c2,
#     :ripqp_mono_c3=>ripqp_mono_c3,
#       :ripqp_mono_c4=>ripqp_mono_c4,
#         :ripqp_mono_c5=>ripqp_mono_c5,
    :ripqp_G1_mono=>ripqp_G1_mono,
#     :ripqp_G1_mono_c=>ripqp_G1_mono_c,
#     :ripqp_G1_mono_d=>ripqp_G1_mono_d
                )
stats2 = Dict(#:ripqp_mp1=>ripqp_mp1,
#               :ripqp_mp5=>ripqp_mp5, 
#               :ripqp_mp4=>ripqp_mp4,
#               :ripqp_mp2=>ripqp_mp2,
#               :ripqp_mp_d1=>ripqp_mp_d1,
#               :ripqp_mono3=>ripqp_mono3,
#             :ripqp_G1_multi=>ripqp_G1_multi,
#             :ripqp_G1_multi_d=>ripqp_G1_multi_d
            )
# stats_bis = Dict(:mehrotra8bis=>mehrotra8bis, :mehrotra5bis=>mehrotra5bis, :mehrotra6bis=>mehrotra6bis,
#                 :mehrotra7bis=>mehrotra7bis)

# %%
using Plots
perf = performance_profile(stats, df->df.elapsed_time)
plot!(perf, legend=:bottomright)
title!("profile marosmeszaros qp")

# %%
performance_profile(stats2, df->df.iter)
# Out:
# MethodError: no method matching performance_profile(::Dict{Any,Any}, ::var"#13#14")
# Closest candidates are:
#   performance_profile(!Matched::Dict{Symbol,DataFrame}, ::Function, !Matched::Any...; kwargs...) at C:\Users\Geoffroy Leconte\.julia\packages\SolverBenchmark\5q9Qe\src\profiles.jl:21
#
# Stacktrace:
#  [1] top-level scope at In[18]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
mehrotra9_iter = copy(mehrotra9)
mehrotra9_iter.iter .*= 4
stats_iter = Dict(#:mehrotra9_iter=>mehrotra9_iter, 
#                     :mehrotra_mp1=>mehrotra_mp1, 
#                     :mehrotra_mp2=>mehrotra_mp2,
#                     :mehrotra_mp3=>mehrotra_mp3,
#                     :mehrotra_mp4=>mehrotra_mp4,
#                     :mehrotra_mp5=>mehrotra_mp5,
                    #:mehrotra_mp6=>mehrotra_mp6
#                     :mehrotra_mp7=>mehrotra_mp7,
#                     :ripqp_mp1 => ripqp_mp1,
#                     :ripqp_mp2 => ripqp_mp2,
#                     :ripqp_mp3 => ripqp_mp3,
                    :ripqp_mp4 => ripqp_mp4,
                    :ripqp_mp5 => ripqp_mp5,
                    )
# Out:
# UndefVarError: mehrotra9 not defined
#
# Stacktrace:
#  [1] top-level scope at In[9]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [3] execute_code(::String, ::String) at C:\Users\Geoffroy Leconte\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Geoffroy Leconte\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:86
#  [5] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [6] invokelatest at .\essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at C:\Users\Geoffroy Leconte\.julia\packages\IJulia\rWZ9e\src\eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at .\task.jl:356

# %%
idx_bad = findall(mehrotra9_iter.iter .< mehrotra_mp3.iter)
println([string(name, ".SIF") for name in mehrotra9_iter.name[idx_bad]])
idx_good = findall(mehrotra9_iter.iter .>= ripqp_mp3.iter);
# Out:
# UndefVarError: mehrotra9_iter not defined
#
# Stacktrace:
#  [1] top-level scope at In[11]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [3] execute_code(::String, ::String) at C:\Users\Geoffroy Leconte\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Geoffroy Leconte\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:86
#  [5] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [6] invokelatest at .\essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at C:\Users\Geoffroy Leconte\.julia\packages\IJulia\rWZ9e\src\eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at .\task.jl:356

# %%
performance_profile(stats_iter, df->df.iter)
# Out:
# UndefVarError: stats_iter not defined
#
# Stacktrace:
#  [1] top-level scope at In[12]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [3] execute_code(::String, ::String) at C:\Users\Geoffroy Leconte\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Geoffroy Leconte\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:86
#  [5] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [6] invokelatest at .\essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at C:\Users\Geoffroy Leconte\.julia\packages\IJulia\rWZ9e\src\eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at .\task.jl:356

# %%
ripqp_iter = copy(ripqp_mono3)
ripqp_iter.iter ./=4
stats_iter = Dict(:ripqp_iter=>ripqp_iter,
                  :gurobi4=>gurobi4
                    )
performance_profile(stats_iter, df->df.iter)

# %%
idx_bad = findall(ripqp_mono3.elapsed_time .< ripqp_mono_c1.elapsed_time)
println([string(name, ".SIF") for name in ripqp_mono3.name[idx_bad]])
plot(ripqp_mono3.ncon[idx_bad])
# Out:
# ["AUG2DC.SIF", "AUG2DCQP.SIF", "AUG2DQP.SIF", "AUG3D.SIF", "AUG3DC.SIF", "AUG3DCQP.SIF", "AUG3DQP.SIF", "BOYD2.SIF", "CONT-050.SIF", "CONT-100.SIF", "CONT-200.SIF", "CONT-201.SIF", "CVXQP1_S.SIF", "CVXQP2_M.SIF", "CVXQP2_S.SIF", "CVXQP3_S.SIF", "DPKLO1.SIF", "DUAL1.SIF", "DUAL2.SIF", "DUAL3.SIF", "DUAL4.SIF", "DUALC1.SIF", "DUALC2.SIF", "DUALC5.SIF", "DUALC8.SIF", "GENHS28.SIF", "GOULDQP2.SIF", "GOULDQP3.SIF", "HS118.SIF", "HS21.SIF", "HS268.SIF", "HS35.SIF", "HS51.SIF", "HS52.SIF", "HS53.SIF", "HS76.SIF", "HUES-MOD.SIF", "HUESTIS.SIF", "LASER.SIF", "LISWET1.SIF", "LISWET11.SIF", "LISWET12.SIF", "LISWET2.SIF", "LISWET3.SIF", "LISWET4.SIF", "LISWET5.SIF", "LISWET6.SIF", "LISWET7.SIF", "LISWET8.SIF", "LISWET9.SIF", "LOTSCHD.SIF", "MOSARQP1.SIF", "MOSARQP2.SIF", "POWELL20.SIF", "PRIMAL1.SIF", "PRIMAL2.SIF", "PRIMAL3.SIF", "PRIMAL4.SIF", "PRIMALC1.SIF", "PRIMALC2.SIF", "PRIMALC5.SIF", "PRIMALC8.SIF", "QADLITTL.SIF", "QAFIRO.SIF", "QBANDM.SIF", "QBEACONF.SIF", "QBRANDY.SIF", "QE226.SIF", 
# ...

# %%
#ϵ_pdd = 1e-6
# performance_profile(stats_bis, df->df.elapsed_time)

# %%
using Plots
plot(ripqp_mp3.iter[idx_good], label="iter_mp")
plot!(mehrotra9_iter.iter[idx_good], label="iter")

# %%
using DataFrames, Query

# %%
xpress_qp  = @from i in xpress2 begin
        @select {i.name, i.nvar, i.ncon, i.status, i.objective, i.elapsed_time, i.iter, i.primal_feas, i.dual_feas}
        @collect DataFrame
end
# Out:
# 123×9 DataFrame. Omitted printing of 3 columns
# │ Row │ name     │ nvar  │ ncon   │ status     │ objective  │ elapsed_time │
# │     │ String   │ Int64 │ Int64  │ Symbol     │ Float64    │ Float64      │
# ├─────┼──────────┼───────┼────────┼────────────┼────────────┼──────────────┤
# │ 1   │ AUG2D    │ 20200 │ 10000  │ acceptable │ 1.68741e6  │ 0.195423     │
# │ 2   │ AUG2DC   │ 20200 │ 10000  │ acceptable │ 1.81837e6  │ 0.168693     │
# │ 3   │ AUG2DCQP │ 20200 │ 10000  │ acceptable │ 6.49813e6  │ 2.32885      │
# │ 4   │ AUG2DQP  │ 20200 │ 10000  │ acceptable │ 6.23701e6  │ 2.13073      │
# │ 5   │ AUG3D    │ 3873  │ 1000   │ acceptable │ 554.068    │ 0.0733988    │
# │ 6   │ AUG3DC   │ 3873  │ 1000   │ acceptable │ 771.262    │ 0.066608     │
# │ 7   │ AUG3DCQP │ 3873  │ 1000   │ acceptable │ 993.362    │ 0.227094     │
# │ 8   │ AUG3DQP  │ 3873  │ 1000   │ acceptable │ 675.238    │ 0.203856     │
# │ 9   │ BOYD1    │ 93261 │ 18     │ acceptable │ -6.17352e7 │ 2.19275      │
# ...

# %%
 save_path = raw"C:\Users\Geoffroy Leconte\Documents\cours\TFE\code\results\ripqp"
 #save_path = "C:\\Users\\Geoffroy Leconte\\Documents\\cours\\TFE\\code\\results"
 open(string(save_path, "/xpress2_qp.tex"), "w") do io
   pretty_latex_stats(io, xpress_qp)
 end
